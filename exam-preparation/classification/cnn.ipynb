# %%
# %pip install numpy pandas seaborn torch torchvision scikit-learn matplotlib graphviz tqdm torchsummary sympy
# Out:
# Requirement already satisfied: numpy in /Users/kitton/Desktop/Workspace/github/intro-to-ml-and-dl/.venv/lib/python3.13/site-packages (2.3.3)
# Requirement already satisfied: pandas in /Users/kitton/Desktop/Workspace/github/intro-to-ml-and-dl/.venv/lib/python3.13/site-packages (2.3.3)
# Requirement already satisfied: seaborn in /Users/kitton/Desktop/Workspace/github/intro-to-ml-and-dl/.venv/lib/python3.13/site-packages (0.13.2)
# Requirement already satisfied: torch in /Users/kitton/Desktop/Workspace/github/intro-to-ml-and-dl/.venv/lib/python3.13/site-packages (2.8.0)
# Requirement already satisfied: torchvision in /Users/kitton/Desktop/Workspace/github/intro-to-ml-and-dl/.venv/lib/python3.13/site-packages (0.23.0)
# Requirement already satisfied: scikit-learn in /Users/kitton/Desktop/Workspace/github/intro-to-ml-and-dl/.venv/lib/python3.13/site-packages (1.7.2)
# Requirement already satisfied: matplotlib in /Users/kitton/Desktop/Workspace/github/intro-to-ml-and-dl/.venv/lib/python3.13/site-packages (3.10.7)
# Requirement already satisfied: graphviz in /Users/kitton/Desktop/Workspace/github/intro-to-ml-and-dl/.venv/lib/python3.13/site-packages (0.21)
# Requirement already satisfied: tqdm in /Users/kitton/Desktop/Workspace/github/intro-to-ml-and-dl/.venv/lib/python3.13/site-packages (4.67.1)
# Requirement already satisfied: torchsummary in /Users/kitton/Desktop/Workspace/github/intro-to-ml-and-dl/.venv/lib/python3.13/site-packages (1.5.1)
# Requirement already satisfied: sympy in /Users/kitton/Desktop/Workspace/github/intro-to-ml-and-dl/.venv/lib/python3.13/site-packages (1.14.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/kitton/Desktop/Workspace/github/intro-to-ml-and-dl/.venv/lib/python3.13/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/kitton/Desktop/Workspace/github/intro-to-ml-and-dl/.venv/lib/python3.13/site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/kitton/Desktop/Workspace/github/intro-to-ml-and-dl/.venv/lib/python3.13/site-packages (from pandas) (2025.2)
# Requirement already satisfied: filelock in /Users/kitton/Desktop/Workspace/github/intro-to-ml-and-dl/.venv/lib/python3.13/site-packages (from torch) (3.20.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /Users/kitton/Desktop/Workspace/github/intro-to-ml-and-dl/.venv/lib/python3.13/site-packages (from torch) (4.15.0)
# Requirement already satisfied: setuptools in /Users/kitton/Desktop/Workspace/github/intro-to-ml-and-dl/.venv/lib/python3.13/site-packages (from torch) (80.9.0)
# Requirement already satisfied: networkx in /Users/kitton/Desktop/Workspace/github/intro-to-ml-and-dl/.venv/lib/python3.13/site-packages (from torch) (3.5)
# Requirement already satisfied: jinja2 in /Users/kitton/Desktop/Workspace/github/intro-to-ml-and-dl/.venv/lib/python3.13/site-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec in /Users/kitton/Desktop/Workspace/github/intro-to-ml-and-dl/.venv/lib/python3.13/site-packages (from torch) (2025.9.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /Users/kitton/Desktop/Workspace/github/intro-to-ml-and-dl/.venv/lib/python3.13/site-packages (from torchvision) (11.3.0)
# Requirement already satisfied: scipy>=1.8.0 in /Users/kitton/Desktop/Workspace/github/intro-to-ml-and-dl/.venv/lib/python3.13/site-packages (from scikit-learn) (1.16.2)
# Requirement already satisfied: joblib>=1.2.0 in /Users/kitton/Desktop/Workspace/github/intro-to-ml-and-dl/.venv/lib/python3.13/site-packages (from scikit-learn) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /Users/kitton/Desktop/Workspace/github/intro-to-ml-and-dl/.venv/lib/python3.13/site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/kitton/Desktop/Workspace/github/intro-to-ml-and-dl/.venv/lib/python3.13/site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /Users/kitton/Desktop/Workspace/github/intro-to-ml-and-dl/.venv/lib/python3.13/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/kitton/Desktop/Workspace/github/intro-to-ml-and-dl/.venv/lib/python3.13/site-packages (from matplotlib) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/kitton/Desktop/Workspace/github/intro-to-ml-and-dl/.venv/lib/python3.13/site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /Users/kitton/Desktop/Workspace/github/intro-to-ml-and-dl/.venv/lib/python3.13/site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pyparsing>=3 in /Users/kitton/Desktop/Workspace/github/intro-to-ml-and-dl/.venv/lib/python3.13/site-packages (from matplotlib) (3.2.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/kitton/Desktop/Workspace/github/intro-to-ml-and-dl/.venv/lib/python3.13/site-packages (from sympy) (1.3.0)
# Requirement already satisfied: six>=1.5 in /Users/kitton/Desktop/Workspace/github/intro-to-ml-and-dl/.venv/lib/python3.13/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/kitton/Desktop/Workspace/github/intro-to-ml-and-dl/.venv/lib/python3.13/site-packages (from jinja2->torch) (3.0.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
import torch.nn as nn
import torch
import pandas as pd
from sklearn.model_selection import train_test_split

# from sklearn.preprocessing import StandardScaler
from torch.utils.data import DataLoader, TensorDataset
from tqdm import tqdm
import matplotlib.pyplot as plt
import torchvision.transforms as transforms
from torchsummary import summary
import torchvision

# %%
transform = transforms.Compose(
    [transforms.ToTensor(), transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))]
)

training_set = torchvision.datasets.CIFAR10(
    "./data", train=True, transform=transform, download=True
)
validation_set = torchvision.datasets.CIFAR10(
    "./data", train=False, transform=transform, download=True
)

training_loader = torch.utils.data.DataLoader(training_set, batch_size=64, shuffle=True)
validation_loader = torch.utils.data.DataLoader(
    validation_set, batch_size=64, shuffle=False
)

classes = (
    "plane",
    "car",
    "bird",
    "cat",
    "deer",
    "dog",
    "frog",
    "horse",
    "ship",
    "truck",
)

print("Training set has {} instances".format(len(training_set)))
print("Validation set has {} instances".format(len(validation_set)))
# Out:
# Training set has 50000 instances
# Validation set has 10000 instances

# %%
class CNN(nn.Module):
    def __init__(self):
        super(CNN, self).__init__()
        self.features = nn.Sequential(
            nn.Conv2d(3, 32, kernel_size=3, padding=1),
            nn.BatchNorm2d(32),
            nn.ReLU(),
            nn.MaxPool2d(2, 2),
            nn.Dropout(0.3),
            nn.Conv2d(32, 64, kernel_size=3, padding=1),
            nn.BatchNorm2d(64),
            nn.ReLU(),
            nn.MaxPool2d(2, 2),
            nn.Dropout(0.3),
            nn.Conv2d(64, 128, kernel_size=3, padding=1),
            nn.BatchNorm2d(128),
            nn.ReLU(),
            nn.MaxPool2d(2, 2),
            nn.Dropout(0.3),
        )

        self.classifier = nn.Sequential(
            nn.Flatten(),
            nn.Linear(128 * 4 * 4, 512),
            nn.ReLU(),
            nn.Dropout(0.5),
            nn.Linear(512, 256),
            nn.ReLU(),
            nn.Dropout(0.5),
            nn.Linear(256, 10),
        )

    def forward(self, x):
        x = self.features(x)
        x = self.classifier(x)
        return x

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")
# Out:
# Using device: cpu

# %%
import time
import os

model = CNN().to(device)
summary(model, (3, 32, 32))


# DIY: Hyperparameters  -----------------------------------------
# Loss function
loss_fn = nn.CrossEntropyLoss()
# Optimiter
# optimizer = torch.optim.Adam(model.parameters(), lr=0.001)
optimizer = torch.optim.AdamW(model.parameters(), lr=0.001, weight_decay=1e-4)
# DIY: Hyperparameters  -----------------------------------------


epoch_number = 0

EPOCHS = 3
path_save_cp = "./cp/"
best_vloss = 1_000_000.0
training_logs = {
    "train_loss": [],
    "train_acc": [],
    "validate_loss": [],
    "validate_acc": [],
}

t_0 = time.time()
for epoch in range(EPOCHS):
    train_loss, train_correct = 0, 0
    model.train(True)
    for i, data in enumerate(training_loader):
        inputs, labels = data

        # DIY: Training Loop  -----------------------------------------
        optimizer.zero_grad()
        inputs = inputs.to(device)
        labels = labels.to(device)
        outputs = model(inputs)
        loss = loss_fn(outputs, labels)
        loss.backward()
        optimizer.step()
        # DIY: Training Loop  -----------------------------------------

        train_loss += loss.item()
        train_correct += (outputs.argmax(1) == labels).float().sum().item()

    training_logs["train_loss"].append(train_loss / len(training_loader))
    training_logs["train_acc"].append(train_correct / len(training_loader.dataset))

    running_vloss = 0.0
    model.eval()
    valid_loss, valid_correct = 0, 0
    with torch.no_grad():
        for i, vdata in enumerate(validation_loader):
            vinputs, vlabels = vdata
            vinputs = vinputs.to(device)
            vlabels = vlabels.to(device)
            voutputs = model(vinputs)
            vloss = loss_fn(voutputs, vlabels)
            valid_loss += loss_fn(voutputs, vlabels).item()
            valid_correct += (voutputs.argmax(1) == vlabels).float().sum().item()
        # save validation logs
        training_logs["validate_loss"].append(valid_loss / len(validation_loader))
        training_logs["validate_acc"].append(
            valid_correct / len(validation_loader.dataset)
        )

    if epoch % 1 == 0:
        print(
            f"Epochs {epoch + 1}".ljust(10),
            f"train loss {training_logs['train_loss'][-1]:.5f}",
            f"train acc {training_logs['train_acc'][-1]:.5f}",
            f"validate loss {training_logs['validate_loss'][-1]:.5f}",
            f"validate acc {training_logs['validate_acc'][-1]:.5f}",
        )
        print("-" * 80)

    if valid_loss < best_vloss:
        best_vloss = valid_loss
        if not os.path.exists(path_save_cp):
            os.mkdir(path_save_cp)
        torch.save(model.state_dict(), path_save_cp + "best_model.pth")

    epoch_number += 1

t_end = time.time() - t_0
print(f"Time consumption for non-accelerated CUDA training (CPU only): {t_end} sec")
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 32, 32, 32]             896
#        BatchNorm2d-2           [-1, 32, 32, 32]              64
#               ReLU-3           [-1, 32, 32, 32]               0
#          MaxPool2d-4           [-1, 32, 16, 16]               0
#            Dropout-5           [-1, 32, 16, 16]               0
#             Conv2d-6           [-1, 64, 16, 16]          18,496
#        BatchNorm2d-7           [-1, 64, 16, 16]             128
#               ReLU-8           [-1, 64, 16, 16]               0
#          MaxPool2d-9             [-1, 64, 8, 8]               0
#           Dropout-10             [-1, 64, 8, 8]               0
#            Conv2d-11            [-1, 128, 8, 8]          73,856
#       BatchNorm2d-12            [-1, 128, 8, 8]             256
#              ReLU-13            [-1, 128, 8, 8]               0
#         MaxPool2d-14            [-1, 128, 4, 4]               0
#           Dropout-15            [-1, 128, 4, 4]               0
#           Flatten-16                 [-1, 2048]               0
#            Linear-17                  [-1, 512]       1,049,088
#              ReLU-18                  [-1, 512]               0
#           Dropout-19                  [-1, 512]               0
#            Linear-20                  [-1, 256]         131,328
#              ReLU-21                  [-1, 256]               0
#           Dropout-22                  [-1, 256]               0
#            Linear-23                   [-1, 10]           2,570
# ================================================================
# Total params: 1,276,682
# Trainable params: 1,276,682
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.01
# Forward/backward pass size (MB): 1.56
# Params size (MB): 4.87
# Estimated Total Size (MB): 6.45
# ----------------------------------------------------------------
# Epochs 1   train loss 1.60761 train acc 0.40520 validate loss 1.36000 validate acc 0.50960
# --------------------------------------------------------------------------------
# Epochs 2   train loss 1.32710 train acc 0.52366 validate loss 1.10285 validate acc 0.60420
# --------------------------------------------------------------------------------
# Epochs 3   train loss 1.20064 train acc 0.57298 validate loss 1.03627 validate acc 0.63430
# --------------------------------------------------------------------------------
# Time consumption for non-accelerated CUDA training (CPU only): 102.50918388366699 sec

# %%
def plot_graph(history):
    fig, (ax1, ax2) = plt.subplots(1, 2)
    fig.set_figwidth(10)
    fig.suptitle("Train vs Validation")
    ax1.plot(history["train_acc"], label="Train")
    ax1.plot(history["validate_acc"], label="Validation")
    ax1.legend()
    ax1.set_title("Accuracy")

    ax2.plot(history["train_loss"], label="Train")
    ax2.plot(history["validate_loss"], label="Validation")
    ax2.legend()
    ax2.set_title("Loss")
    fig.show()

# %%
plot_graph(training_logs)
# Out:
# /var/folders/ht/sjv3b_3j1971b798q4w64p0c0000gn/T/ipykernel_83272/3436101493.py:14: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
