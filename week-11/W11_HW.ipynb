# %%
# %pip install torch torchvision torchsummary sympy
# Out:
# WARNING: Ignoring invalid distribution ~orch (/home/klamban/anaconda3/envs/kuy_nam/lib/python3.13/site-packages)
# WARNING: Ignoring invalid distribution ~orch (/home/klamban/anaconda3/envs/kuy_nam/lib/python3.13/site-packages)
# Requirement already satisfied: torch in ./anaconda3/envs/kuy_nam/lib/python3.13/site-packages (2.8.0)
# Requirement already satisfied: torchvision in ./anaconda3/envs/kuy_nam/lib/python3.13/site-packages (0.23.0)
# Requirement already satisfied: torchsummary in ./anaconda3/envs/kuy_nam/lib/python3.13/site-packages (1.5.1)
# Requirement already satisfied: sympy in ./anaconda3/envs/kuy_nam/lib/python3.13/site-packages (1.14.0)
# Requirement already satisfied: filelock in ./anaconda3/envs/kuy_nam/lib/python3.13/site-packages (from torch) (3.19.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in ./anaconda3/envs/kuy_nam/lib/python3.13/site-packages (from torch) (4.15.0)
# Requirement already satisfied: setuptools in ./anaconda3/envs/kuy_nam/lib/python3.13/site-packages (from torch) (80.9.0)
# Requirement already satisfied: networkx in ./anaconda3/envs/kuy_nam/lib/python3.13/site-packages (from torch) (3.5)
# Requirement already satisfied: jinja2 in ./anaconda3/envs/kuy_nam/lib/python3.13/site-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec in ./anaconda3/envs/kuy_nam/lib/python3.13/site-packages (from torch) (2025.9.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in ./anaconda3/envs/kuy_nam/lib/python3.13/site-packages (from torch) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in ./anaconda3/envs/kuy_nam/lib/python3.13/site-packages (from torch) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in ./anaconda3/envs/kuy_nam/lib/python3.13/site-packages (from torch) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in ./anaconda3/envs/kuy_nam/lib/python3.13/site-packages (from torch) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in ./anaconda3/envs/kuy_nam/lib/python3.13/site-packages (from torch) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in ./anaconda3/envs/kuy_nam/lib/python3.13/site-packages (from torch) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in ./anaconda3/envs/kuy_nam/lib/python3.13/site-packages (from torch) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in ./anaconda3/envs/kuy_nam/lib/python3.13/site-packages (from torch) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in ./anaconda3/envs/kuy_nam/lib/python3.13/site-packages (from torch) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in ./anaconda3/envs/kuy_nam/lib/python3.13/site-packages (from torch) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.3 in ./anaconda3/envs/kuy_nam/lib/python3.13/site-packages (from torch) (2.27.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in ./anaconda3/envs/kuy_nam/lib/python3.13/site-packages (from torch) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in ./anaconda3/envs/kuy_nam/lib/python3.13/site-packages (from torch) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in ./anaconda3/envs/kuy_nam/lib/python3.13/site-packages (from torch) (1.13.1.3)
# Requirement already satisfied: triton==3.4.0 in ./anaconda3/envs/kuy_nam/lib/python3.13/site-packages (from torch) (3.4.0)
# Requirement already satisfied: numpy in ./anaconda3/envs/kuy_nam/lib/python3.13/site-packages (from torchvision) (2.2.6)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in ./anaconda3/envs/kuy_nam/lib/python3.13/site-packages (from torchvision) (11.3.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in ./anaconda3/envs/kuy_nam/lib/python3.13/site-packages (from sympy) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in ./anaconda3/envs/kuy_nam/lib/python3.13/site-packages (from jinja2->torch) (3.0.3)
# WARNING: Ignoring invalid distribution ~orch (/home/klamban/anaconda3/envs/kuy_nam/lib/python3.13/site-packages)
# WARNING: Ignoring invalid distribution ~orch (/home/klamban/anaconda3/envs/kuy_nam/lib/python3.13/site-packages)
# WARNING: Ignoring invalid distribution ~orch (/home/klamban/anaconda3/envs/kuy_nam/lib/python3.13/site-packages)
# WARNING: Ignoring invalid distribution ~orch (/home/klamban/anaconda3/envs/kuy_nam/lib/python3.13/site-packages)
# Note: you may need to restart the kernel to use updated packages.

# %%
import torch
import torchvision
import torchvision.transforms as transforms
from datetime import datetime
import os
import torch.nn as nn
import torch.nn.functional as F
from torchsummary import summary
import time

# %%
transform = transforms.Compose(
    [transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))])

training_set = torchvision.datasets.CIFAR10('./data', train=True, transform=transform, download=True)
validation_set = torchvision.datasets.CIFAR10('./data', train=False, transform=transform, download=True)

training_loader = torch.utils.data.DataLoader(training_set, batch_size=64, shuffle=True)
validation_loader = torch.utils.data.DataLoader(validation_set, batch_size=64, shuffle=False)

classes = ('plane', 'car', 'bird', 'cat',
           'deer', 'dog', 'frog', 'horse', 'ship', 'truck')

print('Training set has {} instances'.format(len(training_set)))
print('Validation set has {} instances'.format(len(validation_set)))
# Out:
# 100%|██████████| 170M/170M [00:14<00:00, 11.8MB/s]
# Training set has 50000 instances
# Validation set has 10000 instances

# %%
import matplotlib.pyplot as plt
import numpy as np

def matplotlib_imshow(img, one_channel=False):
    if one_channel:
        img = img.mean(dim=0)
    img = img / 2 + 0.5
    npimg = img.numpy()
    if one_channel:
        plt.imshow(npimg)
    else:
        plt.imshow(np.transpose(npimg, (1, 2, 0)))

dataiter = iter(training_loader)
images, labels = next(dataiter)

img_grid = torchvision.utils.make_grid(images)
matplotlib_imshow(img_grid, one_channel=True)
print('  '.join(classes[labels[j]] for j in range(4)))
# Out:
# bird  truck  deer  truck

# %%
def plot_graph(history):
    fig, (ax1, ax2) = plt.subplots(1, 2)
    fig.set_figwidth(10)
    fig.suptitle("Train vs Validation")
    ax1.plot(history["train_acc"], label="Train")
    ax1.plot(history["validate_acc"], label="Validation")
    ax1.legend()
    ax1.set_title("Accuracy")

    ax2.plot(history["train_loss"], label="Train")
    ax2.plot(history["validate_loss"], label="Validation")
    ax2.legend()
    ax2.set_title("Loss")
    fig.show()

# %% [markdown]
# # HW
# ให้เติมโค้ดในส่วนที่กำหนดเพื่อให้สามารถรันโค้ดได้ตามปกติ
# ```
# # DIY: A  -----------------------------------------
#  < ----- ให้เขียนโค้ดในช่วงนี้
#  < ----- ให้เขียนโค้ดในช่วงนี้
#  < ----- ให้เขียนโค้ดในช่วงนี้
# # DIY: A  -----------------------------------------
# ```
# - ออกแบบและสร้าง โมเดล CNN ที่สามารถทำให้ Accuracy ≥ 50% บน Dataset ที่กำหนด
# - เมื่อทำเสร็จแล้ว ให้ แคปภาพค่า Loss และ Accuracy ระหว่างการ Train
# - บันทึกเป็นไฟล์ PDF และแนบมาพร้อมกับ ภาพแคป Layers ทั้งหมดของโมเดลที่ใช้

# %%
class CNN(nn.Module):
    def __init__(self):
        super(CNN, self).__init__()
        self.features = nn.Sequential(
            nn.Conv2d(3, 32, kernel_size=3, padding=1),
            nn.BatchNorm2d(32),
            nn.ReLU(),
            nn.MaxPool2d(2, 2),
            nn.Dropout(0.3),

            nn.Conv2d(32, 64, kernel_size=3, padding=1),
            nn.BatchNorm2d(64),
            nn.ReLU(),
            nn.MaxPool2d(2, 2),
            nn.Dropout(0.3),

            nn.Conv2d(64, 128, kernel_size=3, padding=1),
            nn.BatchNorm2d(128),
            nn.ReLU(),
            nn.MaxPool2d(2, 2),
            nn.Dropout(0.3),
        )

        self.classifier = nn.Sequential(
            nn.Flatten(),
            nn.Linear(128 * 4 * 4, 512),
            nn.ReLU(),
            nn.Dropout(0.5),

            nn.Linear(512, 256),
            nn.ReLU(),
            nn.Dropout(0.5),

            nn.Linear(256, 10)
        )

    def forward(self, x):
        x = self.features(x)
        x = self.classifier(x)
        return x

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")
# Out:
# Using device: cuda

# %%
model = CNN().to(device)
summary(model, (3, 32, 32))


# DIY: Hyperparameters  -----------------------------------------
# Loss function
loss_fn = nn.CrossEntropyLoss()
# Optimiter
# optimizer = torch.optim.Adam(model.parameters(), lr=0.001)
optimizer = torch.optim.AdamW(model.parameters(), lr=0.001, weight_decay=1e-4)
# DIY: Hyperparameters  -----------------------------------------


epoch_number = 0

EPOCHS = 20
path_save_cp = './cp/'
best_vloss = 1_000_000.
training_logs = {"train_loss": [],  "train_acc": [], "validate_loss": [], "validate_acc": []}

t_0 = time.time()
for epoch in range(EPOCHS):
    train_loss, train_correct = 0, 0
    model.train(True)
    for i, data in enumerate(training_loader):
        inputs, labels = data

        # DIY: Training Loop  -----------------------------------------
        optimizer.zero_grad()
        inputs = inputs.to(device)
        labels = labels.to(device)
        outputs = model(inputs)
        loss = loss_fn(outputs, labels)
        loss.backward()
        optimizer.step()
        # DIY: Training Loop  -----------------------------------------


        train_loss += loss.item()
        train_correct += (outputs.argmax(1) == labels).float().sum().item()

    training_logs["train_loss"].append(train_loss / len(training_loader))
    training_logs["train_acc"].append(train_correct / len(training_loader.dataset))

    running_vloss = 0.0
    model.eval()
    valid_loss, valid_correct = 0, 0
    with torch.no_grad():
        for i, vdata in enumerate(validation_loader):
            vinputs, vlabels = vdata
            vinputs = vinputs.to(device)
            vlabels = vlabels.to(device)
            voutputs = model(vinputs)
            vloss = loss_fn(voutputs, vlabels)
            valid_loss += loss_fn(voutputs, vlabels).item()
            valid_correct += (voutputs.argmax(1) == vlabels).float().sum().item()
        # save validation logs
        training_logs["validate_loss"].append(valid_loss / len(validation_loader))
        training_logs["validate_acc"].append(valid_correct / len(validation_loader.dataset))

    if epoch % 1 == 0:
        print(f"Epochs {epoch+1}".ljust(10),
            f"train loss {training_logs['train_loss'][-1]:.5f}",
            f"train acc {training_logs['train_acc'][-1]:.5f}",

            f"validate loss {training_logs['validate_loss'][-1]:.5f}",
            f"validate acc {training_logs['validate_acc'][-1]:.5f}",
            )
        print("-"*80)

    if valid_loss < best_vloss:
        best_vloss = valid_loss
        if not os.path.exists(path_save_cp): os.mkdir(path_save_cp)
        torch.save(model.state_dict(), path_save_cp+'best_model.pth')

    epoch_number += 1

t_end = time.time()-t_0
print(f"Time consumption for non-accelerated CUDA training (CPU only): {t_end} sec")
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 32, 32, 32]             896
#        BatchNorm2d-2           [-1, 32, 32, 32]              64
#               ReLU-3           [-1, 32, 32, 32]               0
#          MaxPool2d-4           [-1, 32, 16, 16]               0
#            Dropout-5           [-1, 32, 16, 16]               0
#             Conv2d-6           [-1, 64, 16, 16]          18,496
#        BatchNorm2d-7           [-1, 64, 16, 16]             128
#               ReLU-8           [-1, 64, 16, 16]               0
#          MaxPool2d-9             [-1, 64, 8, 8]               0
#           Dropout-10             [-1, 64, 8, 8]               0
#            Conv2d-11            [-1, 128, 8, 8]          73,856
#       BatchNorm2d-12            [-1, 128, 8, 8]             256
#              ReLU-13            [-1, 128, 8, 8]               0
#         MaxPool2d-14            [-1, 128, 4, 4]               0
#           Dropout-15            [-1, 128, 4, 4]               0
#           Flatten-16                 [-1, 2048]               0
#            Linear-17                  [-1, 512]       1,049,088
#              ReLU-18                  [-1, 512]               0
#           Dropout-19                  [-1, 512]               0
#            Linear-20                  [-1, 256]         131,328
#              ReLU-21                  [-1, 256]               0
#           Dropout-22                  [-1, 256]               0
#            Linear-23                   [-1, 10]           2,570
# ================================================================
# Total params: 1,276,682
# Trainable params: 1,276,682
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.01
# Forward/backward pass size (MB): 1.56
# Params size (MB): 4.87
# Estimated Total Size (MB): 6.45
# ----------------------------------------------------------------
# Epochs 1   train loss 1.63303 train acc 0.39530 validate loss 1.30346 validate acc 0.52430
# --------------------------------------------------------------------------------
# Epochs 2   train loss 1.31981 train acc 0.52534 validate loss 1.08038 validate acc 0.60410
# --------------------------------------------------------------------------------
# Epochs 3   train loss 1.18467 train acc 0.58580 validate loss 0.98993 validate acc 0.65930
# --------------------------------------------------------------------------------
# Epochs 4   train loss 1.10441 train acc 0.61588 validate loss 0.92254 validate acc 0.67440
# --------------------------------------------------------------------------------
# Epochs 5   train loss 1.04893 train acc 0.63868 validate loss 0.87482 validate acc 0.68930
# --------------------------------------------------------------------------------
# Epochs 6   train loss 0.98972 train acc 0.65822 validate loss 0.82492 validate acc 0.72150
# --------------------------------------------------------------------------------
# Epochs 7   train loss 0.95706 train acc 0.67216 validate loss 0.79560 validate acc 0.72350
# --------------------------------------------------------------------------------
# Epochs 8   train loss 0.92351 train acc 0.68372 validate loss 0.77012 validate acc 0.73450
# --------------------------------------------------------------------------------
# Epochs 9   train loss 0.89341 train acc 0.69428 validate loss 0.75596 validate acc 0.73410
# --------------------------------------------------------------------------------
# Epochs 10  train loss 0.87140 train acc 0.70342 validate loss 0.72999 validate acc 0.74800
# --------------------------------------------------------------------------------
# Epochs 11  train loss 0.84682 train acc 0.71138 validate loss 0.70839 validate acc 0.75220
# --------------------------------------------------------------------------------
# Epochs 12  train loss 0.83114 train acc 0.71620 validate loss 0.70615 validate acc 0.75650
# --------------------------------------------------------------------------------
# Epochs 13  train loss 0.81962 train acc 0.72284 validate loss 0.68198 validate acc 0.76620
# --------------------------------------------------------------------------------
# Epochs 14  train loss 0.80203 train acc 0.73150 validate loss 0.69228 validate acc 0.75620
# --------------------------------------------------------------------------------
# Epochs 15  train loss 0.78775 train acc 0.73366 validate loss 0.67472 validate acc 0.76840
# --------------------------------------------------------------------------------
# Epochs 16  train loss 0.77937 train acc 0.73640 validate loss 0.65371 validate acc 0.77800
# --------------------------------------------------------------------------------
# Epochs 17  train loss 0.76679 train acc 0.74248 validate loss 0.66552 validate acc 0.77400
# --------------------------------------------------------------------------------
# Epochs 18  train loss 0.75451 train acc 0.74476 validate loss 0.66290 validate acc 0.76760
# --------------------------------------------------------------------------------
# Epochs 19  train loss 0.75035 train acc 0.74714 validate loss 0.64358 validate acc 0.78100
# --------------------------------------------------------------------------------
# Epochs 20  train loss 0.73636 train acc 0.75034 validate loss 0.61793 validate acc 0.78800
# --------------------------------------------------------------------------------
# Time consumption for non-accelerated CUDA training (CPU only): 224.688006401062 sec

# %%
plot_graph(training_logs)
